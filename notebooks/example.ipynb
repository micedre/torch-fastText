# %% [markdown]
# # Example usage of the `torchTextClassifiers` library
#
# *Warning*
#
# *`torchTextClassifiers` library is still under active development. Have a
# regular look to <https://github.com/inseefrlab/torchTextClassifiers> for
# latest information.*
#
# To install package, you can run the following snippet

# %%
# Stable version
# !uv pip install scikit-learn numpy torch unidecode captum nltk

# Development version
# pip install git+https://github.com/InseeFrLab/torchTextClassifiers.git
# Out:
# Using Python 3.13.5 environment at: /home/onyxia/work/torch-fastText/.venv
# Resolved 46 packages in 1.19s
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)--------------     0 B/42.81 KiB
# ⠙ Preparing packages... (0/5)-------------- 14.84 KiB/42.81 KiB
# ⠙ Preparing packages... (0/5)-------------- 14.84 KiB/42.81 KiB
# typing-extensions    ------------------------------ 14.84 KiB/42.81 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/15.86 MiB
# typing-extensions    ------------------------------ 14.84 KiB/42.81 KiB
# ⠙ Preparing packages... (0/5)-------------- 14.88 KiB/15.86 MiB
# typing-extensions    ------------------------------ 30.84 KiB/42.81 KiB
# ⠙ Preparing packages... (0/5)-------------- 14.88 KiB/15.86 MiB
# typing-extensions    ------------------------------ 42.81 KiB/42.81 KiB
# ⠙ Preparing packages... (0/5)-------------- 14.88 KiB/15.86 MiB
# ⠙ Preparing packages... (0/5)-------------- 14.88 KiB/15.86 MiB
# ⠙ Preparing packages... (0/5)-------------- 30.88 KiB/15.86 MiB
# ⠙ Preparing packages... (0/5)-------------- 30.88 KiB/15.86 MiB
# networkx             ------------------------------     0 B/1.94 MiB
# ⠙ Preparing packages... (0/5)-------------- 30.88 KiB/15.86 MiB
# networkx             ------------------------------     0 B/1.94 MiB
# ⠙ Preparing packages... (0/5)-------------- 30.88 KiB/15.86 MiB
# networkx             ------------------------------     0 B/1.94 MiB
# ⠙ Preparing packages... (0/5)-------------- 30.88 KiB/15.86 MiB
# networkx             ------------------------------     0 B/1.94 MiB
# numpy                ------------------------------ 30.88 KiB/15.86 MiB
# ⠙ Preparing packages... (0/5)--------------     0 B/783.00 MiB
# networkx             ------------------------------     0 B/1.94 MiB
# numpy                ------------------------------ 30.88 KiB/15.86 MiB
# ⠙ Preparing packages... (0/5)--------------     0 B/783.00 MiB
# networkx             ------------------------------     0 B/1.94 MiB
# numpy                ------------------------------ 30.88 KiB/15.86 MiB
# ⠙ Preparing packages... (0/5)--------------     0 B/783.00 MiB
# networkx             ------------------------------     0 B/1.94 MiB
# numpy                ------------------------------ 30.88 KiB/15.86 MiB
# ⠙ Preparing packages... (0/5)--------------     0 B/783.00 MiB
# networkx             ------------------------------     0 B/1.94 MiB
# numpy                ------------------------------ 30.88 KiB/15.86 MiB
# triton               ------------------------------     0 B/148.46 MiB
# ⠙ Preparing packages... (0/5)--------------     0 B/783.00 MiB
# networkx             ------------------------------ 46.88 KiB/1.94 MiB
# numpy                ------------------------------ 94.88 KiB/15.86 MiB
# triton               ------------------------------ 16.00 KiB/148.46 MiB
# ⠙ Preparing packages... (0/5)-------------- 62.88 KiB/783.00 MiB
# networkx             ------------------------------ 78.78 KiB/1.94 MiB
# numpy                ------------------------------ 94.88 KiB/15.86 MiB
# triton               ------------------------------ 224.00 KiB/148.46 MiB
# ⠙ Preparing packages... (0/5)-------------- 78.88 KiB/783.00 MiB
# networkx             ------------------------------ 238.88 KiB/1.94 MiB
# numpy                ------------------------------ 174.88 KiB/15.86 MiB
# triton               ------------------------------ 352.00 KiB/148.46 MiB
# ⠙ Preparing packages... (0/5)-------------- 255.32 KiB/783.00 MiB
# networkx             ------------------------------ 286.88 KiB/1.94 MiB
# numpy                ------------------------------ 237.64 KiB/15.86 MiB
# triton               ------------------------------ 527.42 KiB/148.46 MiB
# ⠹ Preparing packages... (1/5)--------------
MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)2m------------ 460.02 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)2m------------ 462.50 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)2m------------ 465.34 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)2m------------ 468.14 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)----------- 470.70 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)----------- 474.22 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)----------- 478.31 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)----------- 482.47 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)----------- 485.73 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)----------- 488.02 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)----------- 489.84 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)----------- 492.22 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)----------- 494.09 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 496.20 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 498.12 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 500.09 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 502.03 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 504.70 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 507.48 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 510.20 MiB/783.00 MiB
# ⠙ Preparing packages... (4/5)---------- 513.08 MiB/783.00 MiB
# ⠙ Preparing packages... (4/5)---------- 515.42 MiB/783.00 MiB
# ⠙ Preparing packages... (4/5)---------- 517.97 MiB/783.00 MiB
# ⠙ Preparing packages... (4/5)---------- 520.78 MiB/783.00 MiB
# ⠹ Preparing packages... (4/5)---------- 523.83 MiB/783.00 MiB
# ⠹ Preparing packages... (4/5)---------- 526.95 MiB/783.00 MiB
# ⠹ Preparing packages... (4/5)---------- 530.00 MiB/783.00 MiB
# ⠹ Preparing packages... (4/5)---------- 532.89 MiB/783.00 MiB
# ⠸ Preparing packages... (4/5)---------- 535.44 MiB/783.00 MiB
# ⠸ Preparing packages... (4/5)---------- 538.36 MiB/783.00 MiB
# ⠸ Preparing packages... (4/5)---------- 541.00 MiB/783.00 MiB
# ⠸ Preparing packages... (4/5)---------- 543.94 MiB/783.00 MiB
# ⠼ Preparing packages... (4/5)---------- 546.78 MiB/783.00 MiB
# ⠼ Preparing packages... (4/5)---------- 549.23 MiB/783.00 MiB
# ⠼ Preparing packages... (4/5)---------- 551.56 MiB/783.00 MiB
# ⠼ Preparing packages... (4/5)---------- 553.72 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)---------- 556.01 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)---------- 558.28 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)---------- 560.61 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)---------- 562.92 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)---------- 565.45 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)---------- 567.81 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)---------- 570.05 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)---------- 572.52 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)---------- 574.97 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)---------- 577.25 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)---------- 579.56 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)---------- 582.05 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 584.31 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 587.06 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 589.81 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 592.15 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 594.55 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 596.86 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 599.37 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 601.86 MiB/783.00 MiB
# ⠙ Preparing packages... (4/5)---------- 604.26 MiB/783.00 MiB
# ⠙ Preparing packages... (4/5)---------- 606.92 MiB/783.00 MiB
# ⠙ Preparing packages... (4/5)---------- 609.56 MiB/783.00 MiB
# ⠙ Preparing packages... (4/5)---------- 612.29 MiB/783.00 MiB
# ⠹ Preparing packages... (4/5)---------- 614.81 MiB/783.00 MiB
# ⠹ Preparing packages... (4/5)---------- 617.36 MiB/783.00 MiB
# ⠹ Preparing packages... (4/5)---------- 620.48 MiB/783.00 MiB
# ⠹ Preparing packages... (4/5)---------- 624.34 MiB/783.00 MiB
# ⠸ Preparing packages... (4/5)---------- 628.08 MiB/783.00 MiB
# ⠸ Preparing packages... (4/5)---------- 631.36 MiB/783.00 MiB
# ⠸ Preparing packages... (4/5)---------- 635.36 MiB/783.00 MiB
# ⠸ Preparing packages... (4/5)---------- 639.12 MiB/783.00 MiB
# ⠼ Preparing packages... (4/5)---------- 642.73 MiB/783.00 MiB
# ⠼ Preparing packages... (4/5)---------- 646.75 MiB/783.00 MiB
# ⠼ Preparing packages... (4/5)---------- 650.42 MiB/783.00 MiB
# ⠼ Preparing packages... (4/5)---------- 655.17 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)---------- 660.51 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)---------- 663.78 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)---------- 667.30 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)---------- 670.40 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)---------- 673.26 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)---------- 676.20 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)---------- 678.80 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)---------- 681.73 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)---------- 684.50 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)---------- 687.31 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)---------- 689.87 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)---------- 692.62 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 695.42 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 698.37 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 701.30 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 704.25 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 707.09 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 709.76 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 712.72 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 715.34 MiB/783.00 MiB
# ⠙ Preparing packages... (4/5)---------- 717.17 MiB/783.00 MiB
# ⠙ Preparing packages... (4/5)---------- 717.47 MiB/783.00 MiB
# ⠙ Preparing packages... (4/5)---------- 718.09 MiB/783.00 MiB
# ⠙ Preparing packages... (4/5)---------- 718.98 MiB/783.00 MiB
# ⠹ Preparing packages... (4/5)---------- 719.87 MiB/783.00 MiB
# ⠹ Preparing packages... (4/5)---------- 720.12 MiB/783.00 MiB
# ⠹ Preparing packages... (4/5)---------- 720.81 MiB/783.00 MiB
# ⠹ Preparing packages... (4/5)---------- 722.64 MiB/783.00 MiB
# ⠸ Preparing packages... (4/5)---------- 725.82 MiB/783.00 MiB
# ⠸ Preparing packages... (4/5)---------- 728.78 MiB/783.00 MiB
# ⠸ Preparing packages... (4/5)---------- 731.62 MiB/783.00 MiB
# ⠸ Preparing packages... (4/5)---------- 734.48 MiB/783.00 MiB
# ⠼ Preparing packages... (4/5)---------- 737.37 MiB/783.00 MiB
# ⠼ Preparing packages... (4/5)---------- 740.14 MiB/783.00 MiB
# ⠼ Preparing packages... (4/5)---------- 742.97 MiB/783.00 MiB
# ⠼ Preparing packages... (4/5)---------- 745.81 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)---------- 748.61 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)---------- 751.64 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)---------- 754.48 MiB/783.00 MiB
# ⠴ Preparing packages... (4/5)---------- 757.19 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)---------- 760.11 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)---------- 762.86 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)---------- 765.65 MiB/783.00 MiB
# ⠦ Preparing packages... (4/5)---------- 768.45 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)---------- 770.98 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)---------- 772.83 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)---------- 775.70 MiB/783.00 MiB
# ⠧ Preparing packages... (4/5)---------- 778.34 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 778.86 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 779.36 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 780.06 MiB/783.00 MiB
# ⠇ Preparing packages... (4/5)---------- 780.36 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 780.58 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 780.80 MiB/783.00 MiB
# ⠋ Preparing packages... (4/5)---------- 781.09 MiB/783.00 MiB
# Prepared 5 packages in 30.69s
# Installed 46 packages in 248ms
#  + captum==0.7.0
#  + click==8.2.1
#  + contourpy==1.3.2
#  + cycler==0.12.1
#  + filelock==3.18.0
#  + fonttools==4.58.4
#  + fsspec==2025.5.1
#  + jinja2==3.1.6
#  + joblib==1.5.1
#  + kiwisolver==1.4.8
#  + markupsafe==3.0.2
#  + matplotlib==3.10.3
#  + mpmath==1.3.0
#  + networkx==3.5
#  + nltk==3.9.1
#  + numpy==2.3.1
#  + nvidia-cublas-cu12==12.6.4.1
#  + nvidia-cuda-cupti-cu12==12.6.80
#  + nvidia-cuda-nvrtc-cu12==12.6.77
#  + nvidia-cuda-runtime-cu12==12.6.77
#  + nvidia-cudnn-cu12==9.5.1.17
#  + nvidia-cufft-cu12==11.3.0.4
#  + nvidia-cufile-cu12==1.11.1.6
#  + nvidia-curand-cu12==10.3.7.77
#  + nvidia-cusolver-cu12==11.7.1.2
#  + nvidia-cusparse-cu12==12.5.4.2
#  + nvidia-cusparselt-cu12==0.6.3
#  + nvidia-nccl-cu12==2.26.2
#  + nvidia-nvjitlink-cu12==12.6.85
#  + nvidia-nvtx-cu12==12.6.77
#  + packaging==25.0
#  + pillow==11.2.1
#  + pyparsing==3.2.3
#  + python-dateutil==2.9.0.post0
#  + regex==2024.11.6
#  + scikit-learn==1.7.0
#  + scipy==1.16.0
#  + setuptools==80.9.0
#  + six==1.17.0
#  + sympy==1.14.0
#  + threadpoolctl==3.6.0
#  + torch==2.7.1
#  + tqdm==4.67.1
#  + triton==3.3.1
#  + typing-extensions==4.14.0
#  + unidecode==1.4.0

# %%
# !uv pip install -e ..
# Out:
# Using Python 3.13.5 environment at: /home/onyxia/work/torch-fastText/.venv
# Resolved 106 packages in 693ms
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastText
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastText
# ⠙ Preparing packages... (0/13)
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
# fastapi              ------------------------------ 14.88 KiB/93.28 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
# fastapi              ------------------------------ 14.88 KiB/93.28 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
# fastapi              ------------------------------ 14.88 KiB/93.28 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
# fastapi              ------------------------------ 14.88 KiB/93.28 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
# fastapi              ------------------------------ 14.88 KiB/93.28 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
# fastapi              ------------------------------ 14.88 KiB/93.28 KiB
# multidict            ------------------------------     0 B/249.10 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
# fastapi              ------------------------------ 14.88 KiB/93.28 KiB
# multidict            ------------------------------ 16.00 KiB/249.10 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
# fastapi              ------------------------------ 14.88 KiB/93.28 KiB
# multidict            ------------------------------ 16.00 KiB/249.10 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
# fastapi              ------------------------------ 14.88 KiB/93.28 KiB
# multidict            ------------------------------ 16.00 KiB/249.10 KiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 14.91 KiB/64.85 KiB
# fastapi              ------------------------------ 14.88 KiB/93.28 KiB
# propcache            ------------------------------ 128.00 KiB/201.53 KiB
# frozenlist           ------------------------------ 223.56 KiB/226.79 KiB
# multidict            ------------------------------ 206.91 KiB/249.10 KiB
# yarl                 ------------------------------ 16.00 KiB/344.35 KiB
# pytorch-lightning    ------------------------------ 13.39 KiB/806.02 KiB
# torchmetrics         ------------------------------ 32.00 KiB/940.08 KiB
# aiohttp              ------------------------------ 16.00 KiB/1.63 MiB
# mlflow-skinny        ------------------------------ 16.00 KiB/1.84 MiB
# pandas               ------------------------------ 16.00 KiB/11.47 MiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 30.91 KiB/64.85 KiB
# fastapi              ------------------------------ 46.88 KiB/93.28 KiB
# propcache            ------------------------------ 201.53 KiB/201.53 KiB
# multidict            ------------------------------ 249.10 KiB/249.10 KiB
# yarl                 ------------------------------ 304.00 KiB/344.35 KiB
# pytorch-lightning    ------------------------------ 49.47 KiB/806.02 KiB
# torchmetrics         ------------------------------ 64.00 KiB/940.08 KiB
# aiohttp              ------------------------------ 464.00 KiB/1.63 MiB
# mlflow-skinny        ------------------------------ 32.00 KiB/1.84 MiB
# pandas               ------------------------------ 32.00 KiB/11.47 MiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 30.91 KiB/64.85 KiB
# fastapi              ------------------------------ 46.88 KiB/93.28 KiB
# propcache            ------------------------------ 201.53 KiB/201.53 KiB
# yarl                 ------------------------------ 320.00 KiB/344.35 KiB
# pytorch-lightning    ------------------------------ 49.47 KiB/806.02 KiB
# torchmetrics         ------------------------------ 64.00 KiB/940.08 KiB
# aiohttp              ------------------------------ 528.00 KiB/1.63 MiB
# mlflow-skinny        ------------------------------ 47.89 KiB/1.84 MiB
# pandas               ------------------------------ 48.00 KiB/11.47 MiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 30.91 KiB/64.85 KiB
# fastapi              ------------------------------ 46.88 KiB/93.28 KiB
# yarl                 ------------------------------ 336.00 KiB/344.35 KiB
# pytorch-lightning    ------------------------------ 49.47 KiB/806.02 KiB
# torchmetrics         ------------------------------ 77.84 KiB/940.08 KiB
# aiohttp              ------------------------------ 608.00 KiB/1.63 MiB
# mlflow-skinny        ------------------------------ 47.89 KiB/1.84 MiB
# pandas               ------------------------------ 48.00 KiB/11.47 MiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 46.91 KiB/64.85 KiB
# fastapi              ------------------------------ 46.88 KiB/93.28 KiB
# pytorch-lightning    ------------------------------ 70.89 KiB/806.02 KiB
# torchmetrics         ------------------------------ 93.84 KiB/940.08 KiB
# aiohttp              ------------------------------ 719.89 KiB/1.63 MiB
# mlflow-skinny        ------------------------------ 47.89 KiB/1.84 MiB
# pandas               ------------------------------ 48.00 KiB/11.47 MiB
#    Building torchtextclassifiers @ file:///home/onyxia/work/torch-fastTextA
# ⠙ Preparing packages... (0/13)
# uvicorn              ------------------------------ 62.91 KiB/64.85 KiB
# fastapi              ------------------------------ 78.88 KiB/93.28 KiB
# pytorch-lightning    ------------------------------ 86.89 KiB/806.02 KiB
# torchmetrics         ------------------------------
# ⠹ Preparing packages... (8/13)------------- 1.63 MiB/23.53 MiB
# pandas               ------------------------------ 1.75 MiB/11.47 MiB
# ⠹ Preparing packages... (8/13)------------- 2.63 MiB/23.53 MiB
# pandas               ------------------------------ 1.85 MiB/11.47 MiB
# ⠸ Preparing packages... (11/13)------------ 2.81 MiB/23.53 MiB
# pandas               ------------------------------ 2.47 MiB/11.47 MiB
# ⠸ Preparing packages... (11/13)------------ 3.37 MiB/23.53 MiB
# pandas               ------------------------------ 3.06 MiB/11.47 MiB
# ⠸ Preparing packages... (11/13)------------ 5.04 MiB/23.53 MiB
# pandas               ------------------------------ 3.93 MiB/11.47 MiB
# ⠸ Preparing packages... (11/13)------------ 5.84 MiB/23.53 MiB
# pandas               ------------------------------ 5.58 MiB/11.47 MiB
# ⠼ Preparing packages... (11/13)------------ 7.72 MiB/23.53 MiB
# pandas               ------------------------------ 6.31 MiB/11.47 MiB
# ⠼ Preparing packages... (11/13)------------ 10.32 MiB/23.53 MiB
# pandas               ------------------------------ 7.30 MiB/11.47 MiB
# ⠼ Preparing packages... (11/13)------------ 11.92 MiB/23.53 MiB
# pandas               ------------------------------ 8.63 MiB/11.47 MiB
# ⠼ Preparing packages... (11/13)------------ 14.11 MiB/23.53 MiB
# pandas               ------------------------------ 10.00 MiB/11.47 MiB
# ⠴ Preparing packages... (11/13)--------- 16.20 MiB/23.53 MiB
# pandas               ------------------------------ 11.37 MiB/11.47 MiB
# ⠴ Preparing packages... (11/13)-------- 17.11 MiB/23.53 MiB
# ⠴ Preparing packages... (11/13)-------- 17.11 MiB/23.53 MiB
# ⠴ Preparing packages... (11/13)-------- 17.61 MiB/23.53 MiB
# ⠴ Preparing packages... (11/13)-------- 19.20 MiB/23.53 MiB
# ⠦ Preparing packages... (12/13)-------- 20.36 MiB/23.53 MiB
# ⠦ Preparing packages... (12/13)-------- 21.17 MiB/23.53 MiB
# ⠦ Preparing packages... (12/13)-------- 21.94 MiB/23.53 MiB
# ⠦ Preparing packages... (12/13)-------- 22.65 MiB/23.53 MiB
# ⠧ Preparing packages... (12/13)-------- 22.81 MiB/23.53 MiB
# ⠧ Preparing packages... (12/13)-------- 22.99 MiB/23.53 MiB
# ⠧ Preparing packages... (12/13)-------- 23.21 MiB/23.53 MiB
# Prepared 13 packages in 1.32s
# Installed 64 packages in 355ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.12.13
#  + aiosignal==1.3.2
#  + alembic==1.16.2
#  + annotated-types==0.7.0
#  + anyio==4.9.0
#  + attrs==25.3.0
#  + blinker==1.9.0
#  + cachetools==5.5.2
#  + certifi==2025.6.15
#  + charset-normalizer==3.4.2
#  + cloudpickle==3.1.1
#  + databricks-sdk==0.57.0
#  + docker==7.1.0
#  + fastapi==0.115.14
#  + flask==3.1.1
#  + frozenlist==1.7.0
#  + gitdb==4.0.12
#  + gitpython==3.1.44
#  + google-auth==2.40.3
#  + graphene==3.4.3
#  + graphql-core==3.2.6
#  + graphql-relay==3.2.0
#  + greenlet==3.2.3
#  + gunicorn==23.0.0
#  + h11==0.16.0
#  + idna==3.10
#  + importlib-metadata==8.7.0
#  + itsdangerous==2.2.0
#  + lightning-utilities==0.14.3
#  + mako==1.3.10
#  + mlflow==3.1.1
#  + mlflow-skinny==3.1.1
#  + multidict==6.6.2
#  + opentelemetry-api==1.34.1
#  + opentelemetry-sdk==1.34.1
#  + opentelemetry-semantic-conventions==0.55b1
#  + pandas==2.3.0
#  + propcache==0.3.2
#  + protobuf==6.31.1
#  + pyarrow==20.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pydantic==2.11.7
#  + pydantic-core==2.33.2
#  + pytorch-lightning==2.5.2
#  + pytz==2025.2
#  + pyyaml==6.0.2
#  + requests==2.32.4
#  + rsa==4.9.1
#  + smmap==5.0.2
#  + sniffio==1.3.1
#  + sqlalchemy==2.0.41
#  + sqlparse==0.5.3
#  + starlette==0.46.2
#  + torchmetrics==1.7.3
#  + torchtextclassifiers==0.0.0.dev0 (from file:///home/onyxia/work/torch-fastText)
#  + typing-inspection==0.4.1
#  + tzdata==2025.2
#  + urllib3==2.5.0
#  + uvicorn==0.35.0
#  + werkzeug==3.1.3
#  + yarl==1.20.1
#  + zipp==3.23.0

# %% [markdown]
# # Load and preprocess data
#
# In that guide, we propose to illustrate main package functionalities
# using that `DataFrame`:

# %%
import pandas as pd
df = pd.read_parquet("https://minio.lab.sspcloud.fr/projet-ape/extractions/20241027_sirene4.parquet")
#df = df.sample(10000)

# %% [markdown]
# Our goal will be to build multilabel classification for the `code`
# variable using `libelle` as feature.
#
# ## Enriching our test dataset
#
# Unlike `Fasttext`, this package offers the possibility of having several
# feature columns of different types (string for the text column and
# additional variables in numeric form, for example). To illustrate that,
# we propose the following enrichment of the example dataset:

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

def categorize_surface(
    df: pd.DataFrame, surface_feature_name: int, like_sirene_3: bool = True
) -> pd.DataFrame:
    """
    Categorize the surface of the activity.

    Args:
        df (pd.DataFrame): DataFrame to categorize.
        surface_feature_name (str): Name of the surface feature.
        like_sirene_3 (bool): If True, categorize like Sirene 3.

    Returns:
        pd.DataFrame: DataFrame with a new column "surf_cat".
    """
    df_copy = df.copy()
    df_copy[surface_feature_name] = df_copy[surface_feature_name].replace("nan", np.nan)
    df_copy[surface_feature_name] = df_copy[surface_feature_name].astype(float)
    # Check surface feature exists
    if surface_feature_name not in df.columns:
        raise ValueError(f"Surface feature {surface_feature_name} not found in DataFrame.")
    # Check surface feature is a float variable
    if not (pd.api.types.is_float_dtype(df_copy[surface_feature_name])):
        raise ValueError(f"Surface feature {surface_feature_name} must be a float variable.")

    if like_sirene_3:
        # Categorize the surface
        df_copy["surf_cat"] = pd.cut(
            df_copy[surface_feature_name],
            bins=[0, 120, 400, 2500, np.inf],
            labels=["1", "2", "3", "4"],
        ).astype(str)
    else:
        # Log transform the surface
        df_copy["surf_log"] = np.log(df[surface_feature_name])

        # Categorize the surface
        df_copy["surf_cat"] = pd.cut(
            df_copy.surf_log,
            bins=[0, 3, 4, 5, 12],
            labels=["1", "2", "3", "4"],
        ).astype(str)

    df_copy[surface_feature_name] = df_copy["surf_cat"].replace("nan", "0")
    df_copy[surface_feature_name] = df_copy[surface_feature_name].astype(int)
    df_copy = df_copy.drop(columns=["surf_log", "surf_cat"], errors="ignore")
    return df_copy


def clean_and_tokenize_df(
    df,
    categorical_features=["EVT", "CJ", "NAT", "TYP", "CRT"],
    text_feature="libelle_processed",
    label_col="apet_finale",
):
    df.fillna("nan", inplace=True)

    df = df.rename(
        columns={
            "evenement_type": "EVT",
            "cj": "CJ",
            "activ_nat_et": "NAT",
            "liasse_type": "TYP",
            "activ_surf_et": "SRF",
            "activ_perm_et": "CRT",
        }
    )

    les = []
    for col in categorical_features:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])
        les.append(le)

    df = categorize_surface(df, "SRF", like_sirene_3=True)
    df = df[[text_feature, "EVT", "CJ", "NAT", "TYP", "SRF", "CRT", label_col]]

    return df, les


def stratified_split_rare_labels(X, y, test_size=0.2, min_train_samples=1):
    # Get unique labels and their frequencies
    unique_labels, label_counts = np.unique(y, return_counts=True)

    # Separate rare and common labels
    rare_labels = unique_labels[label_counts == 1]

    # Create initial mask for rare labels to go into training set
    rare_label_mask = np.isin(y, rare_labels)

    # Separate data into rare and common label datasets
    X_rare = X[rare_label_mask]
    y_rare = y[rare_label_mask]
    X_common = X[~rare_label_mask]
    y_common = y[~rare_label_mask]

    # Split common labels stratified
    X_common_train, X_common_test, y_common_train, y_common_test = train_test_split(
        X_common, y_common, test_size=test_size, stratify=y_common
    )

    # Combine rare labels with common labels split
    X_train = np.concatenate([X_rare, X_common_train])
    y_train = np.concatenate([y_rare, y_common_train])
    X_test = X_common_test
    y_test = y_common_test

    return X_train, X_test, y_train, y_test

def add_libelles(
    df: pd.DataFrame,
    df_naf: pd.DataFrame,
    y: str,
    text_feature: str,
    textual_features: list,
    categorical_features: list,
):
    missing_codes = set(df_naf["code"])
    fake_obs = df_naf[df_naf["code"].isin(missing_codes)]
    fake_obs[y] = fake_obs["code"]
    fake_obs[text_feature] = fake_obs[[text_feature]].apply(
        lambda row: " ".join(f"[{col}] {val}" for col, val in row.items() if val != ""), axis=1
    )
    df = pd.concat([df, fake_obs[[col for col in fake_obs.columns if col in df.columns]]])

    if textual_features is not None:
        for feature in textual_features:
            df[feature] = df[feature].fillna(value="")
    if categorical_features is not None:
        for feature in categorical_features:
            df[feature] = df[feature].fillna(value="NaN")

    print(f"\t*** {len(missing_codes)} codes have been added in the database...\n")
    return df

# %%
categorical_features = ["evenement_type", "cj",  "activ_nat_et", "liasse_type", "activ_surf_et", "activ_perm_et"]
text_feature = "libelle"
y = "apet_finale"
textual_features = None

naf2008 = pd.read_csv("https://minio.lab.sspcloud.fr/projet-ape/data/naf2008.csv", sep=";")
df = add_libelles(df, naf2008, y, text_feature, textual_features, categorical_features)
# Out:
# 	*** 732 codes have been added in the database...

# %% [markdown]
# ## Preprocessing
#
# To reduce noise in text fields, we recommend pre-processing before
# training a model with our package. We assume this preprocessing is
# handled by the package user : this gives him the opportunity to control
# data cleansing.
#
# Here’s an example of the type of preprocessing that can be carried out
# before moving on to the modeling phase

# %%
from torchTextClassifiers.utilities.preprocess import clean_text_feature
df["libelle_processed"] = clean_text_feature(df["libelle"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from torchTextClassifiers.utilities.preprocess import clean_text_feature
#       2 df["libelle_processed"] = clean_text_feature(df["libelle"])
#
# ModuleNotFoundError: No module named 'torchTextClassifiers'

# %% [markdown]
# Right now, the model requires the label (variable y) to be a numerical
# variable. If the label variable is a text variable, we recommend using
# Scikit Learn’s
# [LabelEncoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)
# to convert into a numeric variable. Using that function will give user
# the possibility to get back labels from the encoder after running
# predictions.

# %%
encoder = LabelEncoder()
df["apet_finale"] = encoder.fit_transform(df["apet_finale"])

# %% [markdown]
# The function `clean_and_tokenize_df` requires special `DataFrame`
# formatting:
#
# -   First column contains the processed text (str)
# -   Next ones contain the “encoded” categorical (discrete) variables in
#     int format

# %%
df, _ = clean_and_tokenize_df(df, text_feature="libelle_processed")
X = df[["libelle_processed", "EVT", "CJ", "NAT", "TYP", "CRT", "SRF"]].values
y = df["apet_finale"].values
# Out:
# /tmp/ipykernel_90631/2075507147.py:60: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("nan", inplace=True)

# %% [markdown]
# ## Splitting in train-test sets
#
# As usual in a learning approach, you need to break down your data into
# learning and test/validation samples to obtain robust performance
# statistics.
#
# This work is the responsibility of the package’s users. Here’s an
# example of how to do it, using the
# [`train_test_split`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)
# function in `Scikit`.

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# # Build the torchTextClassifiers FastText model (without training it)
#
# There are several ways to define and train a FastText model in
# this package.
#
# We first show how to initialize the model and then afterwards build it.
#
# `create_fasttext` function accepts the following parameters:
#
# | Parameter | Meaning | Example Value |
# |---------------------|------------------------------------------|----------|
# | `num_tokens` | Number of rows in the embedding matrix (size of the vocabulary) | 100000 |
# | `embedding_dim` | Dimension of the embedding (number of columns in the matrix) | 50 |
# | `sparse` | Use sparse embedding for fast computation (PyTorch) | False |
# | `categorical_embedding_dims` | Dimension of the embedding for categorical features | 10 |
# | `min_count` | Minimum occurrences of a word in the corpus to be included | 1 |
# | `min_n` | Minimum length of character n-grams | 3 |
# | `max_n` | Maximum length of character n-grams | 6 |
# | `len_word_ngrams` | Length of word n-grams | 3 |

# %%
from torchTextClassifiers import create_fasttext

parameters = {
    "num_tokens": 100000,
    "embedding_dim": 50,
    "sparse": False,
    "categorical_embedding_dims": 10,
    "min_count": 1,
    "min_n": 3,
    "max_n": 6,
    "len_word_ngrams": 3,
}

parameters_train = {
    "lr": 0.004,
    "num_epochs": 1,
    "batch_size": 256,
    "patience": 3   
}

model = create_fasttext(**parameters)

# %% [markdown]
# `model` is then a special `torchTextClassifiers` object:

# %%
type(model)

# %% [markdown]
# As any `PyTorch` model, it accepts being save as a JSON for later on
# use:

# %%
model.to_json('torchTextClassifiers_config.json')
# model = create_fasttext.from_json('torchTextClassifiers_config.json')

# %% [markdown]
# We can apply `build` to finally train our model. These are the
# parameters accepted by the `build` method
#
# | Parameter | Meaning | Example Value |
# |---------------------|------------------------------------------|----------|
# | `lr` | Learning rate | 0.004 |
# | `num_epochs` | Number of training epochs | 1 |
# | `batch_size` | Batch size for training | 256 |
# | `patience` | Early stopping patience (number of epochs without improvement) | 3 |
#
# We build the model using the training data. We have now access to the
# tokenizer, the PyTorch model as well as a PyTorch Lightning module ready
# to be trained. Note that Lightning is high-level framework for PyTorch
# that simplifies the process of training, validating, and deploying
# machine learning models.

# %%
model.build(X_train, y_train, lightning=True, lr=parameters_train.get("lr"))
# Out:
# 2025-03-05 16:27:41 - torchFastText.model.pytorch_model - num_rows is different from the number of tokens in the tokenizer. Using provided num_rows.
# 2025-03-05 16:27:41 - torchFastText.torchFastText - No scheduler parameters provided. Using default parameters (suited for ReduceLROnPlateau).

# %% [markdown]
# One can retrieve different objects from `model` instance:
#
# -   `model.pytorch_model`
# -   `model.tokenizer`
# -   `model.lightning_module`

# %%
model.pytorch_model
# Out:
# FastTextModel(
#   (embeddings): EmbeddingBag(107992, 50, mode='mean', padding_idx=107991)
#   (emb_0): Embedding(24, 10)
#   (emb_1): Embedding(40, 10)
#   (emb_2): Embedding(8, 10)
#   (emb_3): Embedding(13, 10)
#   (emb_4): Embedding(3, 10)
#   (emb_5): Embedding(4, 10)
#   (fc): Linear(in_features=60, out_features=646, bias=True)
# )

# %%
model.tokenizer

# %%
model.lightning_module
# Out:
# FastTextModule(
#   (model): FastTextModel(
#     (embeddings): EmbeddingBag(107992, 50, mode='mean', padding_idx=107991)
#     (emb_0): Embedding(24, 10)
#     (emb_1): Embedding(40, 10)
#     (emb_2): Embedding(8, 10)
#     (emb_3): Embedding(13, 10)
#     (emb_4): Embedding(3, 10)
#     (emb_5): Embedding(4, 10)
#     (fc): Linear(in_features=60, out_features=646, bias=True)
#   )
#   (loss): CrossEntropyLoss()
#   (accuracy_fn): MulticlassAccuracy()
# )

# %% [markdown]
# One can also retrieve more precise information regarding the tokenizer.
# This can be useful to know how text is parsed before being given to the
# neural network:

# %%
from pprint import pprint 
sentence = ["lorem ipsum dolor sit amet"]
pprint(model.tokenizer.tokenize(sentence)[2][0])
# Out:
# {0: '</s>',
#  8097: 'lorem ipsum dolor',
#  8172: '<sit',
#  8653: 'sit amet </s>',
#  8949: '<dol',
#  9297: '<amet>',
#  15121: 'lorem>',
#  17369: 'ame',
#  18928: '<am',
#  19903: 'dol',
#  20651: 'amet>',
#  21355: '<lor',
#  22388: 'ips',
#  23844: 'lore',
#  26780: 'dolo',
#  27738: '<si',
#  29478: 'lorem ipsum',
#  31065: 'amet',
#  31980: 'met>',
#  33381: 'or>',
#  35841: 'ipsum dolor',
#  37380: '<ipsum',
#  37409: '<lorem',
#  40410: '<lore',
#  41835: 'dolor sit amet',
#  42838: 'sit',
#  43102: 'sit amet',
#  43464: 'dolor>',
#  44394: '<ips',
#  45021: 'et>',
#  45738: 'sit>',
#  45871: 'ipsu',
#  48778: 'psu',
#  48931: 'orem>',
#  49786: '<dolor',
#  50327: 'lorem',
#  53682: 'um>',
#  57345: 'it>',
#  57990: 'olor>',
#  60515: 'lor>',
#  60522: 'ore',
#  62809: 'sum>',
#  65472: 'met',
#  65559: '<amet',
#  67426: 'em>',
#  67778: 'olor',
#  67985: 'orem',
#  68529: 'psum',
#  69320: '<sit>',
#  72158: 'rem',
#  73818: 'ipsum>',
#  74637: 'dolor sit',
#  76593: 'lor',
#  77594: '<dolo',
#  78022: 'ipsum',
#  82418: 'rem>',
#  87627: '<ame',
#  89926: 'amet </s>',
#  92771: 'psum>',
#  92809: '<ip',
#  94948: 'ipsum dolor sit',
#  97065: '<ipsu',
#  99551: 'sum',
#  102333: '<do',
#  102636: 'dolor',
#  103090: 'olo',
#  106213: '<lo'}

# %% [markdown]
# Saving parameters to JSON can also be done after building, but the model
# needs to be rebuilt after loading.

# %%
model.to_json('torchTextClassifiers_config.json')

# %% [markdown]
# ## Alternative way to build torchTextClassifiers FastText
#
# The training data is only useful to initialize the tokenizer, but
# X_train and y_train are not needed to initialize the PyTorch model,
# provided we give the right parameters to construct layer.
#
# To highlight this, we provide a lower-level process to build the model
# where one can first build the tokenizer, and then build the model with
# custom architecture parameters.
#
# The tokenizer can be loaded **from the same JSON file** as the model
# parameters, or initialized using the right arguments.

# %%
del model

# %% [markdown]
# Let’s decompose our features in two group:
#
# -   We have our textual feature stored in the first column of the
#     features matrix
# -   All other columns are categorical variables

# %%
training_text = X_train[:, 0].tolist()
categorical_variables = X_train[:, 1:]

# %% [markdown]
# We need to create a few variables that will be useful afterwards

# %%
CAT_VOCAB_SIZE = (np.max(categorical_variables, axis=0) + 1).astype(int).tolist()
NUM_CLASSES = len(np.unique(y_train))
NUM_CAT_VAR = categorical_variables.shape[1]

# %% [markdown]
# Now let’s come to the nitty gritty. There are several ways to create an
# instance of the tokenizer.
#
# First, we can create the tokenizer from :
#
# -   model definition in the JSON file created beforehand
# -   textual data in training dataset

# %%
from torchTextClassifiers.classifiers.fasttext.tokenizer import NGramTokenizer
tokenizer = NGramTokenizer.from_json('torchTextClassifiers_config.json', training_text)

# %%
tokenizer.tokenize("Hello world")
# Out:
# ([['<H>', '</s>', 'H </s>'],
#   ['<e>', '</s>', 'e </s>'],
#   ['<l>', '</s>', 'l </s>'],
#   ['<l>', '</s>', 'l </s>'],
#   ['<o>', '</s>', 'o </s>'],
#   ['</s>'],
#   ['<w>', '</s>', 'w </s>'],
#   ['<o>', '</s>', 'o </s>'],
#   ['<r>', '</s>', 'r </s>'],
#   ['<l>', '</s>', 'l </s>'],
#   ['<d>', '</s>', 'd </s>']],
#  [tensor([40876,     0, 51965]),
#   tensor([51907,     0, 77296]),
#   tensor([74312,     0, 26137]),
#   tensor([74312,     0, 26137]),
#   tensor([ 9853,     0, 53786]),
#   tensor([0]),
#   tensor([29925,     0, 74978]),
#   tensor([ 9853,     0, 53786]),
#   tensor([ 8646,     0, 13223]),
#   tensor([74312,     0, 26137]),
#   tensor([ 89472,      0, 104945])],
#  [{40876: '<H>', 0: '</s>', 51965: 'H </s>'},
#   {51907: '<e>', 0: '</s>', 77296: 'e </s>'},
#   {74312: '<l>', 0: '</s>', 26137: 'l </s>'},
#   {74312: '<l>', 0: '</s>', 26137: 'l </s>'},
#   {9853: '<o>', 0: '</s>', 53786: 'o </s>'},
#   {0: '</s>'},
#   {29925: '<w>', 0: '</s>', 74978: 'w </s>'},
#   {9853: '<o>', 0: '</s>', 53786: 'o </s>'},
#   {8646: '<r>', 0: '</s>', 13223: 'r </s>'},
#   {74312: '<l>', 0: '</s>', 26137: 'l </s>'},
#   {89472: '<d>', 0: '</s>', 104945: 'd </s>'}],
#  [{'<H>': 40876, '</s>': 0, 'H </s>': 51965},
#   {'<e>': 51907, '</s>': 0, 'e </s>': 77296},
#   {'<l>': 74312, '</s>': 0, 'l </s>': 26137},
#   {'<l>': 74312, '</s>': 0, 'l </s>': 26137},
#   {'<o>': 9853, '</s>': 0, 'o </s>': 53786},
#   {'</s>': 0},
#   {'<w>': 29925, '</s>': 0, 'w </s>': 74978},
#   {'<o>': 9853, '</s>': 0, 'o </s>': 53786},
#   {'<r>': 8646, '</s>': 0, 'r </s>': 13223},
#   {'<l>': 74312, '</s>': 0, 'l </s>': 26137},
#   {'<d>': 89472, '</s>': 0, 'd </s>': 104945}])

# %% [markdown]
# However, there is a more straightforward way to do: creating directly
# the `NGramTokenizer` instance:

# %%
tokenizer = NGramTokenizer(
    **parameters,
    training_text=training_text
    )

# %%
tokenizer.tokenize("Hello world")
# Out:
# ([['<H>', '</s>', 'H </s>'],
#   ['<e>', '</s>', 'e </s>'],
#   ['<l>', '</s>', 'l </s>'],
#   ['<l>', '</s>', 'l </s>'],
#   ['<o>', '</s>', 'o </s>'],
#   ['</s>'],
#   ['<w>', '</s>', 'w </s>'],
#   ['<o>', '</s>', 'o </s>'],
#   ['<r>', '</s>', 'r </s>'],
#   ['<l>', '</s>', 'l </s>'],
#   ['<d>', '</s>', 'd </s>']],
#  [tensor([40876,     0, 51965]),
#   tensor([51907,     0, 77296]),
#   tensor([74312,     0, 26137]),
#   tensor([74312,     0, 26137]),
#   tensor([ 9853,     0, 53786]),
#   tensor([0]),
#   tensor([29925,     0, 74978]),
#   tensor([ 9853,     0, 53786]),
#   tensor([ 8646,     0, 13223]),
#   tensor([74312,     0, 26137]),
#   tensor([ 89472,      0, 104945])],
#  [{40876: '<H>', 0: '</s>', 51965: 'H </s>'},
#   {51907: '<e>', 0: '</s>', 77296: 'e </s>'},
#   {74312: '<l>', 0: '</s>', 26137: 'l </s>'},
#   {74312: '<l>', 0: '</s>', 26137: 'l </s>'},
#   {9853: '<o>', 0: '</s>', 53786: 'o </s>'},
#   {0: '</s>'},
#   {29925: '<w>', 0: '</s>', 74978: 'w </s>'},
#   {9853: '<o>', 0: '</s>', 53786: 'o </s>'},
#   {8646: '<r>', 0: '</s>', 13223: 'r </s>'},
#   {74312: '<l>', 0: '</s>', 26137: 'l </s>'},
#   {89472: '<d>', 0: '</s>', 104945: 'd </s>'}],
#  [{'<H>': 40876, '</s>': 0, 'H </s>': 51965},
#   {'<e>': 51907, '</s>': 0, 'e </s>': 77296},
#   {'<l>': 74312, '</s>': 0, 'l </s>': 26137},
#   {'<l>': 74312, '</s>': 0, 'l </s>': 26137},
#   {'<o>': 9853, '</s>': 0, 'o </s>': 53786},
#   {'</s>': 0},
#   {'<w>': 29925, '</s>': 0, 'w </s>': 74978},
#   {'<o>': 9853, '</s>': 0, 'o </s>': 53786},
#   {'<r>': 8646, '</s>': 0, 'r </s>': 13223},
#   {'<l>': 74312, '</s>': 0, 'l </s>': 26137},
#   {'<d>': 89472, '</s>': 0, 'd </s>': 104945}])

# %% [markdown]
# Why creating a `NGramTokenizer` separately ? Because model constructor
# is now independent from training data:

# %%
from torchTextClassifiers import build_fasttext_from_tokenizer

model = build_fasttext_from_tokenizer(
    tokenizer, 
    embedding_dim=parameters["embedding_dim"], 
    categorical_embedding_dims=parameters["categorical_embedding_dims"], 
    sparse=parameters["sparse"], 
    lr=parameters_train["lr"], 
    num_classes=NUM_CLASSES, 
    num_categorical_features=NUM_CAT_VAR, 
    categorical_vocabulary_sizes=CAT_VOCAB_SIZE
)

# %% [markdown]
# **Warning**:
#
# If the PyTorch model building did not use the training data, please keep
# in mind that its architecture (that you customize here) should match the
# vocabulary size of the categorical variables and the total number of
# class, otherwise the model will raise an error during training.
#
# # Train a torchTextClassifiers FastText model directly
#
# If no advanced customization or PyTorch tuning is necessary, there is a
# direct way of training model.

# %%
model.train(
    X_train,
    y_train,
    X_test,
    y_test,
    num_epochs=parameters_train['num_epochs'],
    batch_size=parameters_train['batch_size'],
    patience_scheduler=parameters_train['patience'],
    patience_train=parameters_train['patience'],
    lr=parameters_train['lr'],
    verbose = True
)

# %% [markdown]
# # Load a trained model from a Lightning checkpoint
#
# /! TOCOMPLETE

# %%
model.load_from_checkpoint(model.best_model_path) # or any other checkpoint path (string)

# %% [markdown]
# # Predicting from new labels

# %%
text = ["coiffeur, boulangerie, pâtisserie"] # one text description
X= np.array([[text[0], 0, 0, 0, 0, 0, 0]]) # our new entry
TOP_K = 5

pred, conf = model.predict(X, top_k=TOP_K)
pred_naf = encoder.inverse_transform(pred.reshape(-1))
subset = naf2008.set_index("code").loc[np.flip(pred_naf)]

for i in range(TOP_K-1, -1, -1):
    print(f"Prediction: {pred_naf[i]}, confidence:  {conf[0, i]}, description: {subset['libelle'][pred_naf[i]]}")

# %% [markdown]
# # Explainability

# %%
# Note: Visualization functions are not yet implemented in torchTextClassifiers
# The predict_and_explain method is available but visualization utilities need to be implemented

pred, conf, all_scores, all_scores_letters = model.predict_and_explain(X)

# TODO: Implement visualization functions
# visualize_word_scores(all_scores, text, pred_naf.reshape(1, -1))
# visualize_letter_scores(all_scores_letters, text, pred_naf.reshape(1, -1))

print("Predictions with explanations:")
print(f"Predicted classes: {pred}")
print(f"Confidence scores: {conf}")
print(f"Word-level explanation scores shape: {all_scores.shape if hasattr(all_scores, 'shape') else type(all_scores)}")
print(f"Letter-level explanation scores shape: {all_scores_letters.shape if hasattr(all_scores_letters, 'shape') else type(all_scores_letters)}")
